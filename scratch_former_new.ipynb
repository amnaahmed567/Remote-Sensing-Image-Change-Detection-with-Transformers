# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/mustansarfiaz/ScratchFormer.git
# Out:
# Cloning into 'ScratchFormer'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 118 (delta 11), reused 1 (delta 0), pack-reused 95 (from 1)
# Receiving objects: 100% (118/118), 504.48 KiB | 14.41 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# %cd /content/ScratchFormer
# Out:
# /content/ScratchFormer

# %%
pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.2 MB/s eta 0:00:00
# ...

# %%
# !python /content/ScratchFormer/main_cd.py
# Out:
# True
# [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# initialize network with normal
# cuda:0
# ================ (Sun Sep  8 12:42:12 2024) ================
# ...
