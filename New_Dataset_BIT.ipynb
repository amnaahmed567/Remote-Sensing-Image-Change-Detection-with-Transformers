# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: list all the file names in /content/drive/MyDrive/New Dataset/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/New Dataset/A')

# Print the file names
for file in files:
  print(file)
# Out:
# patch_1_0_0.png
# patch_1_0_1.png
# patch_1_0_2.png
# patch_1_0_3.png
# patch_1_1_0.png
# patch_1_1_1.png
# patch_1_1_2.png
# patch_1_1_3.png
# patch_1_2_0.png
# patch_1_2_1.png
# patch_1_2_2.png
# patch_1_2_3.png
# patch_1_3_0.png
# patch_1_3_1.png
# patch_1_3_2.png
# patch_1_3_3.png
# patch_6_0_0.png
# patch_6_0_1.png
# patch_6_0_2.png
# patch_6_0_3.png
# patch_6_1_0.png
# patch_6_1_1.png
# patch_6_1_2.png
# patch_6_1_3.png
# patch_6_2_0.png
# patch_6_2_1.png
# patch_6_2_2.png
# patch_6_2_3.png
# patch_6_3_0.png
# patch_6_3_1.png
# patch_6_3_2.png
# patch_6_3_3.png
# patch_7_0_0.png
# patch_7_0_1.png
# patch_7_0_2.png
# patch_7_0_3.png
# patch_7_1_0.png
# patch_7_1_1.png
# patch_7_1_2.png
# patch_7_1_3.png
# patch_7_2_0.png
# patch_7_2_1.png
# patch_7_2_2.png
# patch_7_2_3.png
# patch_7_3_0.png
# patch_7_3_1.png
# patch_7_3_2.png
# patch_7_3_3.png
# patch_4_0_0.png
# patch_4_0_1.png
# patch_4_0_2.png
# patch_4_1_0.png
# patch_4_1_1.png
# patch_4_1_2.png
# patch_4_2_0.png
# ...

# %%
# prompt: dispaly the number of files in /content/drive/MyDrive/New Dataset/A

print(f"Number of files in the directory: {len(files)}")
# Out:
# Number of files in the directory: 834

# %%
cd /content/drive/MyDrive/BIT_CD_1
# Out:
# /content/drive/MyDrive/BIT_CD_1

# %%
# !sh scripts/run_cd.sh
# Out:
# True
# [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 309MB/s]
# initialize network with normal
# cuda:0
# ================ (Sun Sep  8 11:43:09 2024) ================
# ...

# %%
# !sh scripts/run_cd.sh
# Out:
# True
# [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# initialize network with normal
# cuda:0
# ================ (Sun Sep  8 13:13:45 2024) ================
# ...

# %%
# !sh scripts/eval.sh
# Out:
# True
# [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# initialize network with normal
# cuda:0
# ================ (Sun Sep  8 13:54:05 2024) ================
# gpu_ids: [0] project_name: BIT_LEVIR print_models: False num_workers: 4 dataset: CDDataset data_name: LEVIR batch_size: 8 split: test img_size: 256 n_class: 2 net_G: base_transformer_pos_s4_dd8_dedim8 checkpoint_name: best_ckpt.pt checkpoint_dir: checkpoints/BIT_LEVIR vis_dir: vis/BIT_LEVIR loading last checkpoint...
# ...
