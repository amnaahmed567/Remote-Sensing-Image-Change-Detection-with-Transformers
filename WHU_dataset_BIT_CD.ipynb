# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !kaggle datasets download -d clannaspark/whu-cd
# Out:
# Dataset URL: https://www.kaggle.com/datasets/clannaspark/whu-cd
# License(s): apache-2.0
# whu-cd.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip whu-cd.zip -d LEVIR-CD/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: LEVIR-CD/train/OUT/4041.png
#   inflating: LEVIR-CD/train/OUT/4042.png
#   inflating: LEVIR-CD/train/OUT/4043.png
#   inflating: LEVIR-CD/train/OUT/4044.png
#   inflating: LEVIR-CD/train/OUT/4045.png
#   inflating: LEVIR-CD/train/OUT/4046.png
#   inflating: LEVIR-CD/train/OUT/4047.png
#   inflating: LEVIR-CD/train/OUT/4048.png
#   inflating: LEVIR-CD/train/OUT/4049.png
#   inflating: LEVIR-CD/train/OUT/405.png
#   inflating: LEVIR-CD/train/OUT/4050.png
#   inflating: LEVIR-CD/train/OUT/4051.png
#   inflating: LEVIR-CD/train/OUT/4052.png
#   inflating: LEVIR-CD/train/OUT/4053.png
#   inflating: LEVIR-CD/train/OUT/4054.png
#   inflating: LEVIR-CD/train/OUT/4055.png
#   inflating: LEVIR-CD/train/OUT/4056.png
#   inflating: LEVIR-CD/train/OUT/4057.png
#   inflating: LEVIR-CD/train/OUT/4058.png
#   inflating: LEVIR-CD/train/OUT/4059.png
#   inflating: LEVIR-CD/train/OUT/406.png
#   inflating: LEVIR-CD/train/OUT/4060.png
# ...

# %%
# prompt: name all the files in /content/drive/MyDrive/LEVIR-CD/test/A

import os
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A'):
  print(filename)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1985.png
# 1986.png
# 1987.png
# 1988.png
# 1989.png
# 199.png
# 1990.png
# 1991.png
# 1992.png
# 1993.png
# 1994.png
# 1995.png
# 1996.png
# 1997.png
# 1998.png
# 1999.png
# 2.png
# 20.png
# 200.png
# 2000.png
# 2001.png
# 2002.png
# 2003.png
# 2004.png
# 2005.png
# 2006.png
# 2007.png
# 2008.png
# 2009.png
# 201.png
# 2010.png
# 2011.png
# 2012.png
# 2013.png
# 2014.png
# 2015.png
# 2016.png
# 2017.png
# 2018.png
# 2019.png
# 202.png
# 2020.png
# 2021.png
# 2022.png
# 2023.png
# 2024.png
# 2025.png
# 2026.png
# 2027.png
# 2028.png
# 2029.png
# 203.png
# 2030.png
# 2031.png
# 2032.png
# 2033.png
# 2034.png
# 2035.png
# 2036.png
# 2037.png
# 2038.png
# 2039.png
# 204.png
# 2040.png
# 2041.png
# 2042.png
# 2043.png
# 2044.png
# 2045.png
# 2046.png
# 2047.png
# 2048.png
# 2049.png
# 205.png
# 2050.png
# 2051.png
# 2052.png
# 2053.png
# 2054.png
# 2055.png
# 2056.png
# 2057.png
# 2058.png
# 2059.png
# 206.png
# 2060.png
# 2061.png
# ...

# %%
# prompt: print the number files in /content/drive/MyDrive/LEVIR-CD/test/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/val/A')

# Print the number of files
print(len(files))
# Out:
# 762

# %%
# prompt: print the number files in /content/drive/MyDrive/LEVIR-CD/test/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/test/A')

# Print the number of files
print(len(files))
# Out:
# 762

# %%
# prompt: print the number files in /content/drive/MyDrive/LEVIR-CD/test/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A')

# Print the number of files
print(len(files))
# Out:
# 6096

# %%
# prompt: name all the files in /content/drive/MyDrive/LEVIR-CD/test/A

import os
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/test/A'):
  print(filename)
# Out:
# 0.png
# 1.png
# 10.png
# 100.png
# 101.png
# 102.png
# 103.png
# 104.png
# 105.png
# 106.png
# 107.png
# 108.png
# 109.png
# 11.png
# 110.png
# 111.png
# 112.png
# 113.png
# 114.png
# 115.png
# 116.png
# 117.png
# 118.png
# 119.png
# 12.png
# 120.png
# 121.png
# 122.png
# 123.png
# 124.png
# 125.png
# 126.png
# 127.png
# 128.png
# 129.png
# 13.png
# 130.png
# 131.png
# 132.png
# 133.png
# 134.png
# 135.png
# 136.png
# 137.png
# 138.png
# 139.png
# 14.png
# 140.png
# 141.png
# 142.png
# 143.png
# 144.png
# 145.png
# 146.png
# 147.png
# 148.png
# 149.png
# 15.png
# 150.png
# 151.png
# 152.png
# 153.png
# 154.png
# 155.png
# 156.png
# 157.png
# 158.png
# 159.png
# 16.png
# 160.png
# 161.png
# 162.png
# 163.png
# 164.png
# 165.png
# 166.png
# 167.png
# 168.png
# 169.png
# 17.png
# 170.png
# 171.png
# 172.png
# 173.png
# 174.png
# 175.png
# 176.png
# 177.png
# 178.png
# 179.png
# 18.png
# 180.png
# 181.png
# 182.png
# 183.png
# 184.png
# 185.png
# 186.png
# 187.png
# 188.png
# 189.png
# ...

# %%
# prompt: name all the files in /content/drive/MyDrive/LEVIR-CD/test/A

import os
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/val/A'):
  print(filename)
# Out:
# 0.png
# 1.png
# 10.png
# 100.png
# 101.png
# 102.png
# 103.png
# 104.png
# 105.png
# 106.png
# 107.png
# 108.png
# 109.png
# 11.png
# 110.png
# 111.png
# 112.png
# 113.png
# 114.png
# 115.png
# 116.png
# 117.png
# 118.png
# 119.png
# 12.png
# 120.png
# 121.png
# 122.png
# 123.png
# 124.png
# 125.png
# 126.png
# 127.png
# 128.png
# 129.png
# 13.png
# 130.png
# 131.png
# 132.png
# 133.png
# 134.png
# 135.png
# 136.png
# 137.png
# 138.png
# 139.png
# 14.png
# 140.png
# 141.png
# 142.png
# 143.png
# 144.png
# 145.png
# 146.png
# 147.png
# 148.png
# 149.png
# 15.png
# 150.png
# 151.png
# 152.png
# 153.png
# 154.png
# 155.png
# 156.png
# 157.png
# 158.png
# 159.png
# 16.png
# 160.png
# 161.png
# 162.png
# 163.png
# 164.png
# 165.png
# 166.png
# 167.png
# 168.png
# 169.png
# 17.png
# 170.png
# 171.png
# 172.png
# 173.png
# 174.png
# 175.png
# 176.png
# 177.png
# 178.png
# 179.png
# 18.png
# 180.png
# 181.png
# 182.png
# 183.png
# 184.png
# 185.png
# 186.png
# 187.png
# 188.png
# 189.png
# ...

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/B'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/train/B/'+filename,'/content/drive/MyDrive/LEVIR-CD/B')

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/train/A/'+filename,'/content/drive/MyDrive/LEVIR-CD/A')

# %%
# prompt: print the no. of common files between /content/drive/MyDrive/LEVIR-CD/test/A and /content/drive/MyDrive/LEVIR-CD/train/A

import os

# Get the list of files in the directories
test_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/val/A')
train_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/test/A')

# Find the common files
common_files = set(test_files).intersection(set(train_files))

# Print the number of common files
print(len(common_files))
# Out:
# 762

# %%
# prompt: remove all the files common between /content/drive/MyDrive/LEVIR-CD/val/A and /content/drive/MyDrive/LEVIR-CD/train/A from the /content/drive/MyDrive/LEVIR-CD/train/A

import os
import shutil

# Get the list of files in the directories
val_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/val/A')
train_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A')

# Find the common files
common_files = set(val_files).intersection(set(train_files))

# Remove the common files from the train directory
for filename in common_files:
  file_path = os.path.join('/content/drive/MyDrive/LEVIR-CD/train/A', filename)
  if os.path.exists(file_path):
    os.remove(file_path)

# %%
# prompt: print the number files in /content/drive/MyDrive/LEVIR-CD/test/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A')

# Print the number of files
print(len(files))
# Out:
# 5334

# %%
# prompt: print the  last 300 entires of /content/drive/MyDrive/LEVIR-CD/train/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A')

# Print the last 300 entries
for filename in files[-300:]:
  print(filename)
# Out:
# 6034.png
# 6035.png
# 6036.png
# 6037.png
# 6038.png
# 6039.png
# 6040.png
# 6041.png
# 6042.png
# 6043.png
# 6044.png
# 6045.png
# 6046.png
# 6047.png
# 6048.png
# 6049.png
# 6050.png
# 6051.png
# 6052.png
# 6053.png
# 6054.png
# 6055.png
# 6056.png
# 6057.png
# 6058.png
# 6059.png
# 6060.png
# 6061.png
# 6062.png
# 6063.png
# 6064.png
# 6065.png
# 6066.png
# 6067.png
# 6068.png
# 6069.png
# 6070.png
# 6071.png
# 6072.png
# 6073.png
# 6074.png
# 6075.png
# 6076.png
# 6077.png
# 6078.png
# 6079.png
# 6080.png
# 6081.png
# 6082.png
# 6083.png
# 6084.png
# 6085.png
# 6086.png
# 6087.png
# 6088.png
# 6089.png
# 6090.png
# 6091.png
# 6092.png
# 6093.png
# 6094.png
# 6095.png
# 762.png
# 763.png
# 764.png
# 765.png
# 766.png
# 767.png
# 768.png
# 769.png
# 770.png
# 771.png
# 772.png
# 773.png
# 774.png
# 775.png
# 776.png
# 777.png
# 778.png
# 779.png
# 780.png
# 781.png
# 782.png
# 783.png
# 784.png
# 785.png
# 786.png
# 787.png
# 788.png
# 789.png
# 790.png
# 791.png
# 792.png
# ...

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/A'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/train/A/'+filename,'/content/drive/MyDrive/LEVIR-CD/A')

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/val/A'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/val/A/'+filename,'/content/drive/MyDrive/LEVIR-CD/A')

# %%
# prompt: Print the no of files in the /content/drive/MyDrive/LEVIR-CD/A

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/A')

# Print the number of files
print(len(files))
# Out:
# 6096

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/B'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/train/B/'+filename,'/content/drive/MyDrive/LEVIR-CD/B')

# %%
# prompt: Print the no of files in the /content/drive/MyDrive/LEVIR-CD/A

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/train/OUT')

# Print the number of files
print(len(files))
# Out:
# 473

# %%
# prompt: move all the files from /content/drive/MyDrive/LEVIR-CD/train/A to this  /content/drive/MyDrive/LEVIR-CD/A

import shutil
for filename in os.listdir('/content/drive/MyDrive/LEVIR-CD/train/OUT'):
  shutil.move('/content/drive/MyDrive/LEVIR-CD/train/OUT/'+filename,'/content/drive/MyDrive/LEVIR-CD/label')

# %%
# prompt: Print the no of files in the /content/drive/MyDrive/LEVIR-CD/A
import os
# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/label')

# Print the number of files
print(len(files))
# Out:
# 6096

# %%
cd BIT_CD_1
# Out:
# /content/drive/MyDrive/BIT_CD_1

# %%
# !sh scripts/run_cd.sh
# Out:
# True
# [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 302MB/s]
# initialize network with normal
# cuda:0
# ================ (Thu Sep  5 10:20:13 2024) ================
# ...

# %%
# prompt: print all the files in /content/drive/MyDrive/LEVIR-CD/A

import os

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/A')

# Print the filenames
for filename in files:
  print(filename)
# Out:
# 3450.png
# 3424.png
# 3456.png
# 3427.png
# 3451.png
# 3553.png
# 3552.png
# 3549.png
# 3554.png
# 3545.png
# 3540.png
# 3555.png
# 3559.png
# 3551.png
# 3530.png
# 3532.png
# 3529.png
# 3587.png
# 3606.png
# 3610.png
# 3615.png
# 3523.png
# 3528.png
# 3562.png
# 3616.png
# 3567.png
# 3596.png
# 3581.png
# 3536.png
# 3626.png
# 3603.png
# 3539.png
# 3613.png
# 3625.png
# 3624.png
# 3579.png
# 3617.png
# 3601.png
# 3621.png
# 3541.png
# 3560.png
# 3550.png
# 3577.png
# 3575.png
# 3618.png
# 3544.png
# 3546.png
# 3604.png
# 3580.png
# 3526.png
# 3556.png
# 3594.png
# 3522.png
# 3527.png
# 3566.png
# 3534.png
# 3538.png
# 3592.png
# 3543.png
# 3561.png
# 3525.png
# 3715.png
# 3673.png
# 3685.png
# 3719.png
# 3706.png
# 3663.png
# 3641.png
# 3637.png
# 3730.png
# 3670.png
# 3655.png
# 3697.png
# 3644.png
# 3649.png
# 3699.png
# 3688.png
# 3675.png
# 3659.png
# 3679.png
# 3652.png
# 3654.png
# 3645.png
# 3631.png
# 3633.png
# 3665.png
# 3671.png
# 3690.png
# 3701.png
# 3627.png
# ...

# %%
# prompt: print the number of common files between A and B in LEVIR-CD

# Get the list of files in the directories
a_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/A')
b_files = os.listdir('/content/drive/MyDrive/LEVIR-CD/label')

# Find the common files
common_files = set(a_files).intersection(set(b_files))

# Print the number of common files
print(len(common_files))
# Out:
# 3414

# %%
# prompt: PRINT ALL THE FILES IN B

# Get the list of files in the directory
files = os.listdir('/content/drive/MyDrive/LEVIR-CD/B')

# Print the filenames
for filename in files:
  print(filename)
# Out:
# Streaming output truncated to the last 5000 lines.
# 4760.png
# 481.png
# 4836.png
# 4820.png
# 477.png
# 4787.png
# 480.png
# 4810.png
# 4834.png
# 4822.png
# 4819.png
# 4826.png
# 479.png
# 4808.png
# 4805.png
# 4814.png
# 4828.png
# 4784.png
# 4761.png
# 4785.png
# 4821.png
# 4775.png
# 4815.png
# 4804.png
# 48.png
# 4786.png
# 483.png
# 4818.png
# 4776.png
# 4774.png
# 4762.png
# 4799.png
# 4764.png
# 4832.png
# 4755.png
# 4794.png
# 4757.png
# 4781.png
# 4812.png
# 4773.png
# 4783.png
# 4816.png
# 4823.png
# 4789.png
# 4803.png
# 4763.png
# 4791.png
# 4780.png
# 4793.png
# 4833.png
# 4829.png
# 4766.png
# 4792.png
# 4806.png
# 4831.png
# 4798.png
# 4827.png
# 476.png
# 4817.png
# 4825.png
# 4765.png
# 4797.png
# 4769.png
# 4811.png
# 4782.png
# 482.png
# 4779.png
# 4759.png
# 4768.png
# 4767.png
# 4835.png
# 4795.png
# 4778.png
# 4837.png
# 4889.png
# 4873.png
# 4841.png
# 4858.png
# 4895.png
# 486.png
# 4857.png
# 4844.png
# 4878.png
# 4850.png
# 4883.png
# 4879.png
# 4866.png
# ...
